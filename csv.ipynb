# %%
import pandas as pd

# %%
data = {
    "doctor": ["Dr Rahul", "Dr John", "Dr Fathima Izza","Dr Ravi","Dr Sandeep","Dr Abhinav"],
    "department": ["Cardiology","Dermatology","Neurology","Orthopedic","General Medicine","Otolarngology"],
    "time": ["3PM","3PM", "4PM", "5PM","6PM","5PM"]
}

# %%
df = pd.DataFrame(data)

# %%
df.to_csv("doctors.csv", index=False)

# %%
import ollama

# %%
#pip install requests
